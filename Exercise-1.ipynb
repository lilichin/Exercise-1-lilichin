# %%
ice_cream_rating=10
sleeping_rating=8
print(ice_cream_rating)
print(sleeping_rating)
# Out:
# 10
# 8

# %%
first_name=input("My firstname is")
last_name=input("My lastname is")
print(first_name)
print(last_name)
my_name=first_name+" "+last_name
print(my_name)
# Out:
# My firstname is Yunfan
# My lastname is Li
# Yunfan
# Li
# Yunfan Li

# %%
happiness_rating=(ice_cream_rating+sleeping_rating)/2
print(happiness_rating)
# Out:
# 9.0

# %%
type(ice_cream_rating)
type(sleeping_rating)
type(happiness_rating)
# Out:
# float

# %%
print("My name is",my_name,"and I give eating ice cream a score of",ice_cream_rating,"out of 10!")
print("I am",my_name,"and my sleeping enjoyment rating is",sleeping_rating,"/ 10!")
print("Based on the factors above, my happiness rating is",happiness_rating,"out of 10, or",happiness_rating/10*100,"%!")
# Out:
# My name is Yunfan Li and I give eating ice cream a score of 10 out of 10!
# I am Yunfan Li and my sleeping enjoyment rating is 8 / 10!
# Based on the factors above, my happiness rating is 9.0 out of 10, or 90.0 %!
